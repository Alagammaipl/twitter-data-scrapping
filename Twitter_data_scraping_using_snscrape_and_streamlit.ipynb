# %% [markdown]
# <a href="https://colab.research.google.com/github/Alagammaipl/twitter-data-scrapping/blob/main/Twitter_data_scraping_using_snscrape_and_streamlit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***installation of snscrape library***

# %%
# !pip3 install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ***scraping tweets***

# %%
# !snscrape --jsonl --progress --max-results 1000 twitter-search adhani > user-tweets.json
# Out:
# Scraping, 100 results so far
# Scraping, 200 results so far
# Scraping, 300 results so far
# Scraping, 400 results so far
# Scraping, 500 results so far
# Scraping, 600 results so far
# Scraping, 700 results so far
# Scraping, 800 results so far
# Scraping, 900 results so far
# Scraping, 1000 results so far
# Stopped scraping after 1000 results due to --max-results

# %% [markdown]
# ***converting to dataframe***

# %%
import pandas as pd
df = pd.read_json("/content/user-tweets.json",  lines=True)
df.head(5)
# Out:
#                             _type  \
# 0  snscrape.modules.twitter.Tweet
# 1  snscrape.modules.twitter.Tweet
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/AakunuriSuresh/status/1620...
# 1  https://twitter.com/SevadalNLG/status/16207316...
# 2  https://twitter.com/harishstarc/status/1620708...
# 3  https://twitter.com/MADGURISrinvas/status/1620...
# 4  https://twitter.com/ICEBOYBILL/status/16206921...
#
#                        date  \
# 0 2023-02-01 10:35:36+00:00
# 1 2023-02-01 10:31:42+00:00
# 2 2023-02-01 09:00:49+00:00
# 3 2023-02-01 08:12:14+00:00
# 4 2023-02-01 07:54:59+00:00
#
#                                           rawContent  \
# 0  @ysathishreddy @KTRBRS @prakashraaj @drgaganbh...
# 1  Where is Asia's richest person!\n#Adhani https...
# 2  Budget 2023 \n\nInda Budget mulamaa indiaya Po...
# ...

# %% [markdown]
# **droping and modifications in df**

# %%
df['date'] = pd.to_datetime(df['date']).dt.date
df
# Out:
#                               _type  \
# 0    snscrape.modules.twitter.Tweet
# 1    snscrape.modules.twitter.Tweet
# 2    snscrape.modules.twitter.Tweet
# 3    snscrape.modules.twitter.Tweet
# 4    snscrape.modules.twitter.Tweet
# ..                              ...
# 995  snscrape.modules.twitter.Tweet
# 996  snscrape.modules.twitter.Tweet
# 997  snscrape.modules.twitter.Tweet
# 998  snscrape.modules.twitter.Tweet
# 999  snscrape.modules.twitter.Tweet
#
#                                                    url        date  \
# 0    https://twitter.com/AakunuriSuresh/status/1620...  2023-02-01
# 1    https://twitter.com/SevadalNLG/status/16207316...  2023-02-01
# 2    https://twitter.com/harishstarc/status/1620708...  2023-02-01
# 3    https://twitter.com/MADGURISrinvas/status/1620...  2023-02-01
# 4    https://twitter.com/ICEBOYBILL/status/16206921...  2023-02-01
# ..                                                 ...         ...
# ...

# %%
df1 = df.drop(['_type', 'conversationId','sourceUrl','links','media','rawContent','quoteCount', 'inReplyToTweetId','inReplyToUser','mentionedUsers','coordinates', 'retweetedTweet', 'quotedTweet','sourceLabel','place',	'hashtags',	'cashtags',	'card','viewCount', 'vibe'], axis = 1)
df1.head()
# Out:
#                                                  url        date  \
# 0  https://twitter.com/AakunuriSuresh/status/1620...  2023-02-01
# 1  https://twitter.com/SevadalNLG/status/16207316...  2023-02-01
# 2  https://twitter.com/harishstarc/status/1620708...  2023-02-01
# 3  https://twitter.com/MADGURISrinvas/status/1620...  2023-02-01
# 4  https://twitter.com/ICEBOYBILL/status/16206921...  2023-02-01
#
#                                      renderedContent                   id  \
# 0  @ysathishreddy @KTRBRS @prakashraaj @drgaganbh...  1620732594320207872
# 1  Where is Asia's richest person!\n#Adhani https...  1620731611443761152
# 2  Budget 2023 \n\nInda Budget mulamaa indiaya Po...  1620708738750623745
# 3  @SujathaGoud6 Telangana la mapia lu paripalana...  1620696513134620672
# 4  @pushpendrakum why we still listen to this Bul...  1620692173737046017
#
#                                                 user  replyCount  \
# ...

# %%
df1['renderedContent']
# Out:
# 0      @ysathishreddy @KTRBRS @prakashraaj @drgaganbh...
# 1      Where is Asia's richest person!\n#Adhani https...
# 2      Budget 2023 \n\nInda Budget mulamaa indiaya Po...
# 3      @SujathaGoud6 Telangana la mapia lu paripalana...
# 4      @pushpendrakum why we still listen to this Bul...
#                              ...
# 995    Nimerelate na hiyi story ya Josh.Mamangu ashai...
# 996    புதிரா இந்தியா என்ற பெயரில் அதானி இந்தியா: 205...
# 997    @Macha_Icon Bro chunga asisahau akikupea bj ad...
# 998    @Siri4BRS Modhi desha drohi. Ramudu peru chepp...
# 999    Adhani Businesses \nalready in Eelam &amp; Sri...
# Name: renderedContent, Length: 1000, dtype: object

# %% [markdown]
# ***streamlit intallation***

# %%
# !pip install -q streamlit

# %%
# !pip install streamlit -q

# %%
# !pip install pyngrok
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from pyngrok import ngrok

# %%
ngrok.set_auth_token('2KlmmvWjpNy6q1qda2ek5eg1VDC_5jWpKTVMqurQ6yA68PHEx')

# %%
# !nohup streamlit run app.py --server.port 80 &
# Out:
# nohup: appending output to 'nohup.out'

# %%
ngrok.connect(port = '8080')
# Out:
# <NgrokTunnel: "http://73ca-35-188-235-25.ngrok.io" -> "http://localhost:80">

# %%
# %%writefile app.py
#importing needed modules

import streamlit as st
import numpy as np
import pandas as pd
import datetime
import pandas as pd
import json
df1 = pd.read_json("/content/user-tweets.json",  lines=True)
df1['date'] = pd.to_datetime(df1['date']).dt.date
df1['time'] = pd.to_datetime(df1['date']).dt.time
df1['date']=df1['date'].astype(str)
df1['time']=df1['time'].astype(str)

#initiallizing mongodb connection
from pymongo import MongoClient
client=MongoClient("mongodb+srv://Alagammai:alagammai@cluster0.tgilzlf.mongodb.net/?retryWrites=true&w=majority")
db=client['twitterscrape']
my_col=db["adhani 1000 recent tweets"]
my_col.insert_many(df1.to_dict(orient='records'))

#creating dataframe and performing cleaning inside the app to be accessed in app
df = pd.read_json("/content/user-tweets.json",  lines=True)

df['date'] = pd.to_datetime(df['date']).dt.date
df['time'] = pd.to_datetime(df['date']).dt.time

@st.cache
# function to convert data to csv and json formats

def convert_df(df):
    return df.to_csv().encode('utf-8')
    return df.to_json().encode('utf-8')

df = df.drop(['_type','time', 'conversationId','sourceUrl','links','media','rawContent','quoteCount', 'inReplyToTweetId','inReplyToUser','mentionedUsers','coordinates', 'retweetedTweet', 'quotedTweet','sourceLabel','place',	'hashtags',	'cashtags',	'card','viewCount', 'vibe'], axis = 1)
# header for app
st.write("Twitter Scrapping")
#getting keywords, tweet count limit, date range from user

keyword = st.text_input('keyword or hastag to be searched', '')
tweetlimit = st.slider('maximum no of tweets', 0, 1000, 0)
start_date = st.date_input("select date range",datetime.date(2023, 1, 1))
end_date = st.date_input("select date range",datetime.date(2023, 2, 1))

# filterting data based on user input and displaying them 

df_filtered = df[df['renderedContent'].str.contains(keyword)]
df2 = df_filtered[df_filtered ['date'] >= start_date]
df3 = df2[df2['date'] <= end_date]
df4= df3.head(tweetlimit)
st.write("filtered data based on your input")
st.write(df4)

# converting datetime format to str as it will be needed for adding collection to mongodb database

df4['date']=df4['date'].astype(str)
data = df4.to_dict(orient = 'records')

#uploading data in database
#x = db.my_col.find({"$and" : [{'renderedContent' : {"$in" : [keyword]}}, {'date': {"$gte" : ISODate(start_date), "$lte" : ISODate(end_date)}}]}).limit(tweetlimit)
#y = data['id']
#db.my_col.find([y])
#x = db.my_col.find({"$and" : [{'renderedContent' : {"$in" : [keyword]}},{'date': {"$gte" : (start_date), "$lte" : (end_date)}}]}).limit(tweetlimit)
#for i in x:
  #print(i)
  #st.write(i)


if st.button('click here to upload'):
    convert = convert_df(df4)

    # creating download options for user

    st.download_button(
      label="Download data as CSV",
      data=convert,
      file_name='scraped data.csv',
      mime='text/csv',)
    st.download_button(label="Download data as json",data=convert,file_name='scraped data.json',mime='text/json')
# Out:
# Overwriting app.py
